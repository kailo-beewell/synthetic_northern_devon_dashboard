# %% [markdown]
# # Aggregate scores and create RAG ratings
#
# Aggregate the synthetic person-level standard survey responses to find the mean scores by area, then generate RAG ratings based on the scores.
#
# ## Set-up
#
# ### Packages and file paths

# %%
# Import required packages
from dataclasses import dataclass
import numpy as np
import os
import pandas as pd

# Import functions from our dashboard package
from kailo_beewell_dashboard.synthesise_aggregate import (
    aggregate_scores, results_by_site_and_group)
from kailo_beewell_dashboard.synthesise_scores import create_rag_ratings
from kailo_beewell_dashboard.topic_labels import (
    topic_name_dict, topic_description_dict)

# %%
# File paths
@dataclass(frozen=True)
class Paths:
    '''Stores paths to data and files'''
    survey = '../../data/survey_data'
    synthetic_data = 'standard_synthetic_data_raw_msoa.csv'
    aggregate_score = 'standard_area_aggregate_scores_rag.csv'


paths = Paths()

# %% [markdown]
# ### Import raw data

# %%
data = pd.read_csv(os.path.join(paths.survey, paths.synthetic_data))
data.head()
# Out:
#    gender  transgender  sexual_orientation  neurodivergent  birth_parent1  \
# 0     4.0          2.0                 6.0             3.0            2.0
# 1     NaN          2.0                 1.0             3.0            3.0
# 2     2.0          3.0                 4.0             1.0            1.0
# 3     2.0          5.0                 5.0             NaN            2.0
# 4     5.0          3.0                 4.0             1.0            1.0
#
#    birth_parent2  birth_you  birth_you_age  autonomy_pressure  \
# 0            NaN        2.0            1.0                2.0
# 1            2.0        3.0            8.0                4.0
# 2            1.0        1.0            1.0                5.0
# 3            2.0        NaN            3.0                1.0
# 4            3.0        3.0            2.0                5.0
#
#    autonomy_express  ...  peer_talk_helpful_lab    peer_talk_if_lab  \
# 0               5.0  ...       Somewhat helpful                 NaN
# 1               2.0  ...                    NaN  Very uncomfortable
# 2               4.0  ...                    NaN    Very comfortable
# 3               2.0  ...                    NaN       Uncomfortable
# 4               2.0  ...       Somewhat helpful                 NaN
#
#    accept_peer_lab  year_group_lab  fsm_lab  sen_lab    ethnicity_lab  \
# 0       Not at all         Year 10  Non-FSM  Non-SEN  Ethnic minority
# 1         Slightly         Year 10  Non-FSM  Non-SEN  Ethnic minority
# 2       Not at all         Year 10  Non-FSM  Non-SEN    White British
# 3              NaN         Year 10  Non-FSM  Non-SEN    White British
# 4       Not at all             NaN  Non-FSM  Non-SEN    White British
#
#    english_additional_lab  school_lab             msoa
# 0                     NaN    School E     Torridge 001
# 1                      No    School D  North Devon 001
# 2                      No    School E  North Devon 007
# 3                      No    School G  North Devon 006
# 4                     Yes    School B     Torridge 003
#
# [5 rows x 280 columns]

# %% [markdown]
# ## Find mean score by MSOA

# %%
# Create version where every question has mean NaN and count 0, to use when a
# school has no pupils of a particular subgroup (i.e. no-one in certain
# FSM/SEN/gender/year)
no_pupils = aggregate_scores(data)
no_pupils['mean'] = np.nan
no_pupils['count'] = 0
no_pupils.head()
# Out:
#                   variable  mean  count
# 0           autonomy_score   NaN      0
# 1  life_satisfaction_score   NaN      0
# 2           optimism_score   NaN      0
# 3          wellbeing_score   NaN      0
# 4             esteem_score   NaN      0

# %%
# Aggregate for each of the possible schools and pupils groups
agg = results_by_site_and_group(
    data=data, agg_func=aggregate_scores, no_pupils=no_pupils,
    group_type='none', site_col='msoa')

# Hide results when n<10
agg.loc[agg['count'] < 10, ['mean', 'count']] = np.nan

agg.head()
# Out:
#                   variable       mean  count             msoa
# 0           autonomy_score  18.437500   16.0  North Devon 001
# 1  life_satisfaction_score   6.041667   24.0  North Devon 001
# 2           optimism_score  12.307692   26.0  North Devon 001
# 3          wellbeing_score  23.230769   13.0  North Devon 001
# 4             esteem_score  11.764706   17.0  North Devon 001

# %%
# Show the data types and presence of null
types = agg.dtypes
null = agg.isnull().any()
pd.DataFrame([types, null]).T
# Out:
#                 0      1
# variable   object  False
# mean      float64   True
# count     float64   True
# msoa       object  False

# %% [markdown]
# ## Set some MSOA to n<10

# %%
agg.loc[agg['msoa'] == 'North Devon 013', ['mean', 'count']] = np.nan

agg.loc[agg['msoa'] == 'North Devon 014', ['mean', 'count']] = np.nan

agg.loc[agg['msoa'] == 'Torridge 007', ['mean', 'count']] = np.nan

# %% [markdown]
# ## Add RAG ratings

# %%
rag = create_rag_ratings(agg)
rag.head()
# Out:
#                   variable       mean  count             msoa  total_pupils  \
# 0           autonomy_score  18.437500   16.0  North Devon 001         426.0
# 1  life_satisfaction_score   6.041667   24.0  North Devon 001         617.0
# 2           optimism_score  12.307692   26.0  North Devon 001         622.0
# 3          wellbeing_score  23.230769   13.0  North Devon 001         466.0
# 4             esteem_score  11.764706   17.0  North Devon 001         391.0
#
#    group_n  group_wt_mean  group_wt_std      lower      upper      rag
# 0     20.0      17.852113      0.724008  17.128105  18.576120  average
# 1     20.0       4.946515      0.479829   4.466687   5.426344    above
# 2     20.0      12.069132      0.446459  11.622673  12.515590  average
# 3     20.0      21.006438      0.939872  20.066566  21.946309    above
# 4     19.0      12.741688      0.587938  12.153750  13.329626    below

# %% [markdown]
# ## Add names and descriptions for the topics

# %%
# Add label column
rag['variable_lab'] = rag['variable'].map(topic_name_dict)

# View the labels
rag[['variable', 'variable_lab']].drop_duplicates()
# Out:
#                     variable                   variable_lab
# 0             autonomy_score                       Autonomy
# 1    life_satisfaction_score              Life satisfaction
# 2             optimism_score                       Optimism
# 3            wellbeing_score        Psychological wellbeing
# 4               esteem_score                    Self-esteem
# 5               stress_score              Stress and coping
# 6           appearance_score     Feelings around appearance
# 7             negative_score                Negative affect
# 8               lonely_score                     Loneliness
# 9              support_score       Supporting own wellbeing
# 10               sleep_score                          Sleep
# 11            physical_score              Physical activity
# 12           free_like_score                      Free time
# 13               media_score               Social media use
# 14              places_score  Places to go and things to do
# 15          staff_talk_score                            NaN
# 16           home_talk_score                            NaN
# 17           peer_talk_score                            NaN
# 18                talk_score         Talking about feelings
# 19              accept_score                     Acceptance
# 20       school_belong_score              School connection
# 21  staff_relationship_score             Support from staff
# 22   home_relationship_score    Support from parents/carers
# 23          home_happy_score               Home environment
# 24           local_env_score              Local environment
# 25             discrim_score                 Discrimination
# 26        belong_local_score               Local connection
# 27              wealth_score                Relative wealth
# 28              future_score           Future opportunities
# 29             climate_score                 Climate change
# 30              social_score           Support from friends
# 31               bully_score                       Bullying

# %%
# Add labels to dataframe
rag['description'] = rag['variable'].map(topic_description_dict)

# View each of the topics and their label
rag[['variable_lab', 'description']].drop_duplicates()
# Out:
#                      variable_lab  \
# 0                        Autonomy
# 1               Life satisfaction
# 2                        Optimism
# 3         Psychological wellbeing
# 4                     Self-esteem
# 5               Stress and coping
# 6      Feelings around appearance
# 7                 Negative affect
# 8                      Loneliness
# 9        Supporting own wellbeing
# 10                          Sleep
# 11              Physical activity
# 12                      Free time
# 13               Social media use
# 14  Places to go and things to do
# 15                            NaN
# 18         Talking about feelings
# 19                     Acceptance
# 20              School connection
# 21             Support from staff
# 22    Support from parents/carers
# 23               Home environment
# 24              Local environment
# 25                 Discrimination
# 26               Local connection
# 27                Relative wealth
# 28           Future opportunities
# 29                 Climate change
# 30           Support from friends
# 31                       Bullying
#
#                                           description
# 0   \nHow 'in control' young people feel of their ...
# 1   \nHow satisfied young people feel with their life
# 2   \nYoung people's hopefulness and confidence fo...
# 3   \nHow positive and generally happy young peopl...
# 4            \nHow much young people value themselves
# 5   \nManaging stress levels and coping with diffi...
# 6   \nYoung people's feelings around the way that ...
# 7   \nThe frequency with which young people experi...
# 8                \nHow often young people feel lonely
# 9   \nYoung people's knowledge on supporting thems...
# 10                  \nHow much sleep young people get
# 11           \nHow physically active young people are
# 12  \nHow often young people can do things that th...
# 13  \nHow much time young people spend on social m...
# 14  \nWhether young people feel there are places t...
# 15                                                NaN
# 18  \nHow positively/negatively young people feel ...
# 19  \nWhether young people feel accepted by differ...
# 20                  \nFeelings of belonging at school
# 21       \nThe support received from adults at school
# 22         \nThe support received from adults at home
# 23  \nYoung people's feelings regarding the home t...
# 24  \nHow young people feel regarding the area whe...
# 25  \nWhether young people feel discriminated against
# 26  \nYoung people's feelings of belonging in thei...
# 27  \nWhether young people feel their family is ri...
# 28  \nHow young people feel regarding the future o...
# 29                 \nWorries regarding climate change
# 30  \nThe support young people receive from their ...
# 31  \nThe frequency with which young people experi...

# %% [markdown]
# ## Save results

# %%
rag.to_csv(os.path.join(paths.survey, paths.aggregate_score),
           index=False, na_rep='NULL')
